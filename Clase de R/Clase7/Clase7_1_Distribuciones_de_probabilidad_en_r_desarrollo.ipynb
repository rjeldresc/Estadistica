# %% [markdown]
# <a href="https://colab.research.google.com/github/majorquev/DBDC_202206_Programacion_en_R_para_ciencia_de_datos/blob/main/Clase7/Clase7_1_Distribuciones_de_probabilidad_en_r_desarrollo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Parte 6: Distribuciones de probabilidad
#
# **Autor:** Miguel Jorquera Viguera.<br>
# **E-mail:** majorquev@gmail.com<br>
# **Ayudante:** Rodrigo Morales<br>
# **E-mail ayudante:** rumorale1@gmail.com
#
# En R podemos obtener valores tanto de las funciones de densidad, distribución de probabilidad, cuantiles de una distribución o bien generar valores aleatorios de diversas distribuciones paramétricas.
# Casi todas las distribuciones que se encuentran implementadas en la librería base de R se referencian de la misma manera.
#
# * Funciones de densidad (PDFs) comienzan con la letra “d.”
# * Funciones de distribución acumulada comienzan con la letra “p.”
# * Funcioenes que retornan quantiles de una distribución comienzan con la letra “q.”
# * Funciones que generan valores aleatorios comienzan con la letra“r.”
#
# Por defecto, en R contamos con una amplia variedad familias de distribuciones enre las que destacan las siguientes.
#
#
#
# **Distribution**| **R name**| **additional arguments**
# -----| -----| -----
# beta |`beta` |shape1, shape2, ncp
# binomial| `binom`| size, prob
# Cauchy|`cauchy` |location, scale
# chi-squared| `chisq`| df, ncp
# exponential| `exp` |rate
# F| `f` |df1, df2, ncp
# gamma |`gamma` |shape, scale
# geometric |`geom` |prob
# hypergeometric| `hyper`| m, n, k
# log-normal| `lnorm` |meanlog, sdlog
# logistic |`logis` |location, scale
# negative| `binomial`| nbinom size, prob
# normal |`norm` |mean, sd
# Poisson| `pois`| lambda
# signed rank |`signrank`| n
# Student’s t| `t`| df, ncp
# uniform |`unif`| min, max
# Weibull| `weibull`| shape, scale
# Wilcoxon |`wilcox`|m, n

# %% [markdown]
# # I) Distribución normal
#
# ## Función de densidad
# $$f(x) = \frac{1}{\sqrt{2 π \sigma^2}} e^{-\frac{1}{2\sigma^2}(x - \mu)^2}$$
#
# ## En R...
#
# * `dnorm(x, mean = 0, sd = 1, log = FALSE)`: Evalúa la función de densidad.
# * `pnorm(q, mean = 0, sd = 1, lower.tail = TRUE, log.p = FALSE)`: Calcula la probabilidad acumulada (función de distribución).
# * `qnorm(p, mean = 0, sd = 1, lower.tail = TRUE, log.p = FALSE)`: Calcula los quantiles de la distribución. (Función inversa de la función de distribución de probabilidad).
# * `rnorm(n, mean = 0, sd = 1)`: Genera muestras aleatroias.
#
#
#
#
# **P1.** Se sabe que la estatura de la población adulta de sexo masculino chilena sigue una distribución normal con media 171,8 cms y una desviación estándar de 5cms
#
# **a)** ¿Cuál es la probabilidad de encontrar de que una persona hombre  adulta tenga una estatura
# menor o igual a 160 cms?

# %%
# pnorm()
#?pnorm
pnorm(160, mean = 171.8, sd = 5)
# Hay un 0.9% de probabilidad de que la persona mida menos de 1.60 mts.
# Out:
# [1] 0.009137468

# %%
?pnorm

# %% [markdown]
#
# **b)** ¿Cuál es la probabilidad de encontrar de que una persona adulta tenga una estatura mayor  a 160 cms?

# %%
#P(estatura > 160) = 1- P(estatura <= 160)
1-pnorm(160, mean = 171.8, sd = 5) # 99% de prob de que un adulto Chileno mida más de 1.60.

#NOTA 
# lower.tail 
pnorm(160, mean = 171.8, sd = 5, lower.tail = F)
# Out:
# [1] 0.9908625
# [1] 0.9908625

# %% [markdown]
# **c)** ¿Cuál es la probabilidad de encontrar una persona con estatura entre 180cms y 190 cms?

# %%
# P(est <= 190) - P(est <= 180) = P(180 <= est <= 190)
pnorm(190, mean = 171.8, sd = 5) - pnorm(180, mean = 171.8, sd = 5)

# Hay un 5% de probabilidad de encontrar una persona con estatura entre 180 y 190.
# Out:
# [1] 0.05036626

# %% [markdown]
# **d)** ¿Cuál es la estatura que corresponde al percentil 90?

# %%
# Cual es la estatura que acumula el 90 % de probabilidad
qnorm(p = 0.9, mean = 171.8, sd = 5)


# Cómo interpretamos este valor
# El 90% de las personas de género masculino,en chile, tiene una estatura menor o igual a 178.2 cms.
# Out:
# [1] 178.2078

# %% [markdown]
# **d)**  Genere una muestra aleatoria de tamaño 1000 y guárdela en un vector llamado _estaturas_, provenientes de una distribución normal con media 171,8 y desviación estandar igual a 5.

# %%
# estaturas
# set.seed(2020) #semilla
(estaturas <- rnorm(1000, mean = 171.8, sd = 5)) # tip: si definen una variable entre paréntesis, esto además de definirla, la muestra en consola
# Out:
#    [1] 166.4676 171.0944 173.2536 176.5939 172.4598 163.9609 169.7099 174.2764
#    [9] 174.8114 172.7445 164.0256 168.0380 176.5370 169.4217 164.7136 171.5207
#   [17] 175.1107 174.9006 168.4522 168.7045 175.1079 178.6112 169.1904 174.6230
#   [25] 166.8361 170.9707 173.6529 171.5125 167.5309 174.1326 170.1524 162.5612
#   [33] 172.4020 169.5132 177.7286 164.2568 167.4135 166.7461 165.9096 159.4520
#   [41] 167.9366 163.2288 172.4231 178.1491 171.0252 165.1702 172.8711 162.8909
#   [49] 175.8546 168.3796 169.6969 177.4903 178.4197 173.9403 167.9109 179.8295
#   [57] 175.9855 177.2101 173.8821 172.0477 172.0848 170.6813 166.2270 176.9240
#   [65] 162.3618 167.4992 180.9427 175.0226 174.1620 161.8164 170.1391 165.2064
#   [73] 170.5104 169.5436 175.5201 175.8552 174.8916 177.6556 174.8949 170.1185
#   [81] 164.9005 173.9834 175.9348 172.8654 167.0670 161.9660 165.0163 172.9546
#   [89] 168.8501 171.9062 172.2504 175.1405 169.9454 164.3044 175.9778 170.4869
#   [97] 181.8843 163.0683 176.8286 168.3698 167.5512 164.6861 167.1356 173.6398
#  [105] 171.9418 180.4239 169.5190 184.3163 174.6609 169.4237 177.0777 176.6118
#  [113] 176.4075 170.9705 164.8195 172.2728 176.5695 172.1115 184.3478 171.1756
#  [121] 167.9737 170.2558 169.7379 166.0310 175.1539 169.9365 173.2785 175.2479
#  [889] 179.2868 179.7874 165.1584 168.0527 164.4978 174.7403 161.1061 176.5393
#  [897] 168.4703 176.2205 167.4605 173.4683 165.8759 170.5127 178.2893 169.4665
#  [905] 165.4602 169.4634 168.6963 174.1756 173.5458 171.1401 167.7891 183.1226
#  [913] 165.7068 175.5089 169.4006 168.9777 169.8374 173.5165 180.9111 179.4346
#  [921] 171.0413 172.1915 165.7085 170.3879 173.0886 174.7483 168.4939 175.2564
#  [929] 185.5360 166.8021 169.8668 172.3842 165.8801 171.8060 180.0956 175.2757
#  [937] 175.3202 171.7804 168.5826 163.9184 171.9107 175.2637 168.9639 174.4258
#  [945] 175.7732 179.2153 177.6196 174.7990 182.6101 166.2111 176.0038 169.6507
#  [953] 181.6616 178.7299 181.4683 176.8101 172.3127 178.7158 167.8551 161.0385
#  [961] 170.1681 171.5555 171.5368 173.2416 178.1883 164.1140 163.9901 173.1074
#  [969] 170.6984 175.1293 165.4944 182.0812 164.3352 164.9930 174.7341 183.5849
#  [977] 167.2355 173.9305 178.7911 170.7870 170.4188 167.9634 174.4775 169.6067
#  [985] 177.0265 173.9816 163.1620 179.4888 167.9935 169.3589 166.2063 170.4958
#  [993] 165.4588 172.4155 179.4766 172.7696 181.1190 170.1629 176.2929 174.7048

# %% [markdown]
# **e)** Mediante la función _hist()_ y la función _curve()_  genere un histograma de la muestra creada y añada la curva de distribución normal con la media y desviación estandar reales.

# %%
## NOTA
# dnorm() evalúa la función de densidad en el argumento dado
dnorm(1.2, mean = 0, sd = 1) # evaluación de la densidad en el punto 1.2, de una distrib. normal con media 1 y sd 0.
# Out:
# [1] 0.1941861

# %%
(mu_est <- mean(estaturas))
(sd_est <- sd(estaturas))
# Out:
# [1] 171.5664
# [1] 5.043144

# %%
# Notar que en un histograma podemos visualizar los conteos o las frecuencias relativas.
hist(estaturas, freq = F, breaks = 20 )
curve(dnorm(x,mean = 171.8, sd = 5), add = T, col = "red")
curve(dnorm(x,mean = mu_est, sd = sd_est), add = T, col = "blue")
# Out:
# Plot with title “Histogram of estaturas”

# %%
?hist

# %%
# Podemos realizar lo mismo con ggplot, aunque con un poco de dificultad adicional
library(ggplot2)
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
df <- data.frame(est = estaturas)

# %%
head(df)
# Out:
#   est
# 1 166.4676
# 2 171.0944
# 3 173.2536
# 4 176.5939
# 5 172.4598
# 6 163.9609

# %% [markdown]
# ## Recordatorio (definición de funciones)
#
# ```
# function(par1, par2, ...){
#     ...
#     return(...)
# }
# ```

# %%
suma <- function(a,b){
  aux <- a+b
  return(aux)
}

# %%
suma(10,5)
# Out:
# [1] 15

# %%
dens <- function(x, mu, devst){
  dnorm(x, mean = mu , sd = devst )
}

# %%
class(dnorm)
class(dens)
# Out:
# [1] "function"
# [1] "function"

# %%
dens(1.2, 0,1)
# Out:
# [1] 0.1941861

# %%
df %>% 
  ggplot() +
  aes(x = est) +
  geom_histogram(
    bins = 20,
    fill = "white",
    color = "black",
    aes(y = ..density..)
  ) +
  stat_function(
    fun = function(x){
      dnorm(x, mean = 171.8 , sd = 5 )
      },
    col = "red") +
  stat_function(
    fun = function(x){
      dnorm(x, mean = mu_est , sd = sd_est )
      },
    col = "blue")
# Out:
# plot without title

# %%
df %>% 
  mutate(dens_real = dnorm(est, mean = 171.8 , sd = 5),
         dens_obs  = dnorm(est, mean = mu_est , sd = sd_est)) %>%
  ggplot() +
  aes(x = est) +
  geom_histogram(
    bins = 20,
    fill = "white",
    color = "black",
    aes(y = ..density..)
  ) +
  geom_line(aes(x = est, y = dens_real), col = "red") +
  geom_line(aes(x = est, y = dens_obs), col = "blue")
# Out:
# plot without title

# %% [markdown]
# # II)Distribucion binomial
# ## Contexto
# Cuando una variable aleatoria representa la cantidad de éxitos en $n$ ensayos independientes de tipo Bernoulli (0 o 1), se dice que dicha variable sigue una distribución binomial.
#
# ## Función de probabilidad
#
#
# $$p(x) = {n\choose x}p^x(1-p)^{n-x}$$
# Donde $n$ es el total de ensayos realizados y $x$ es la cantidad de éxitos observados y $p$ es la probabilidad de éxito del evento de interés. Así, los posibles de $x = 0,1,2,...,n$
#
# ## En R...
#
# * `dbinom(x, size, prob, log = FALSE)`: Evalúa la función de masa. En el caso discreto corresponde a la probabilidad del evento.
# * `pbinom(q, size, prob, lower.tail = TRUE, log.p = FALSE)`: Calcula la probabilidad acumulada.
# * `qbinom(p, size, prob, lower.tail = TRUE, log.p = FALSE)`: Retorna cuantiles de la distribución.
# * `rbinom(n, size, prob)`: Genera muestras aleatorias.
#
# **P2.** Suponga que un spot publicitario de un artículo tiene una tasa de efectividad de 20% sobre una determinada población.
#
# **a)** Suponga que se logra llegar con el spot a 100 personas. ¿Cuál es la probabilidad de que
#  al menos 30  personas compren el artículo ofrecido?

# %%
# Identifiquemos algunos elementos como
# Experimento : Hacer llegar el spot a las 100 personas y registrar el número de clientes que efectivamente compraron el artículo.
# Variable aleatoria : X: "el número de clientes (de los 100) que compraron el artículo"
# Espacio muestral : {0,1,2,...,100}
#-------parámetros de pbinom ---------
#size (n): 100
#prob (p): 0.2

# Observación 
pbinom(30, size = 100, prob = 0.2) # P(X <= 30) 

# P(X > 30)
1-pbinom(30, size = 100, prob = 0.2) # P(X > 30) = P(X >= 31)

# P(X >= 30)
1-pbinom(29, size = 100, prob = 0.2) #P(X >= 30) # Tenemos un 1% de prob de que 30 o más personas compren el artículo
pbinom(29, size = 100, prob = 0.2, lower.tail = F)
# Out:
# [1] 0.9939407
# [1] 0.006059335
# [1] 0.01124898
# [1] 0.01124898

# %%
# ¿Cuál es la probabilidad de que exactamente 30 personas compren el artículo ofrecido?
dbinom(30, size = 100, prob = 0.2) # 0.5% de prob de que exactamente 30 personas compren el artículo.

# ota alternativa
pbinom(30, size = 100, prob = 0.2) - pbinom(29, size = 100, prob = 0.2)# P(X = 30)
# Out:
# [1] 0.005189643
# [1] 0.005189643

# %% [markdown]
# **P3.** En una localidad se sabe que el 70% de las casas tienen un televisor.  Se quiere realizar una encuesta a 8 casas ¿cuál es la probabilidad de que 6 o más de ellas tengan televisor?

# %%
# size = 8  
# prob = 0.7

1-pbinom(5, size = 8, prob = 0.7)
#55% de prob de que 6 o más casas tengan tv.
# Out:
# [1] 0.5517738

# %% [markdown]
# ## Lanzando una moneda
# **P4** Supongamos que una **honesta** se lanza 14 veces y se anota el número veces que se obtuvo cara.
#
# **a)** ¿Cuál es la probabilidad de obtener exactamente 4 caras? ¿y al menos 10?

# %%
#size = n = 14, y prob = p = 0.5 ?
dbinom(4,14,0.5)# 6% de prob de obtener exactamente 4 caras.
# Out:
# [1] 0.06109619

# %%
# P(X >= 10)
1-pbinom(9,14,0.5) # 9% de prob de observar al menos 10 caras.
# Out:
# [1] 0.08978271

# %%
0.3*14
# Out:
# [1] 4.2

# %% [markdown]
#
# **b)** Si se repite el experimento 5 veces.
#
#
# *   ¿Qué proporción de caras se debería esperar?¿y si se repite más veces?
# *   ¿En qué % de casos se obtuvo exactamente 4 caras? ¿ y si se repite más veces?
#
#
#  Utillice la función rbinom para simular el experimento 100 veces.

# %%
# simulamos un experimento binomial
set.seed(2020)
(experimentos <- rbinom(n = 5, size = 14, prob = 0.5))

# 1
mean(experimentos) # En promedio se obtienen en torno a las 7 monedas (50% de los 14 intentos)
# 2 
#% Se obtuvo 0% de casos con 4 caras
# Out:
# [1] 8 6 8 7 5
# [1] 6.8

# %%
set.seed(2020)
(experimentos <- rbinom(n = 100, size = 14, prob = 0.5))
# 1
mean(experimentos) # En promedio se obtienen en torno a las 7 monedas (50% de los 14 intentos)
# Out:
#   [1]  8  6  8  7  5  4  5  6  2  8  8  8  9  7  7  7 10  8  7  6  5  4  9 10  9
#  [26]  5  6  8  7  7 10  4 10 10  2  6  3 10  7  6 11  6  9  9  8  7  7  8  9  5
#  [51]  7  6  9  7  9  2  7  6  7  7  5  7  6  7  9  8 11  7  8  5  8  9  6  7  7
#  [76]  6  6  4  8  8  9  5  6  6  6  5  6  6  5  6  7  8  6  9  7  5  8  5  8  7
# [1] 6.92

# %%
# 2
mean(experimentos == 4)
#  Se obtuvo un 4% de casos con 4 caras
# Out:
# [1] 0.04

# %%
set.seed(2020)
experimentos <- rbinom(n = 1000000, size = 14, prob = 0.5)

# 1
mean(experimentos)

# 2
mean(experimentos == 4)
#  Se obtuvo un 6% de casos con 4 caras
# Out:
# [1] 7.000322
# [1] 0.060963

# %%
# podemos construir un gráfico de barras con los conteos
df <- data.frame(caras  = experimentos)
head(df)
# Out:
#   caras
# 1 8
# 2 6
# 3 8
# 4 7
# 5 5
# 6 4

# %%
df %>% 
  count(caras) %>% 
  arrange(caras)
# Out:
#    caras n
# 1   0        64
# 2   1       818
# 3   2      5520
# 4   3     22236
# 5   4     60963
# 6   5    121890
# 7   6    183738
# 8   7    209521
# 9   8    183365
# 10  9    122522
# 11 10     60773
# 12 11     22034
# 13 12      5630
# 14 13       867
# 15 14        59

# %%
# gráfio ggplot 

df %>% 
    ggplot() +
    aes(x = caras) +
    geom_bar()
# Out:
# plot without title

# %%
# Pero si queremos visualizar las frecuencias relativas observadas?
# Adicionalmente nos interesaría poder visualizar la función de masa de probabilidad.

# %%
(p_est <- mean(experimentos)/14)
# Out:
# [1] 0.500023

# %%
df %>% 
  count(caras) %>%
  arrange(caras) %>%
  mutate(prob_obs = n/1000000,
         prob_real = dbinom(caras, size = 14, prob = 0.5),
         prob_est = dbinom(caras, size = 14, prob = p_est)
         ) %>%
  ggplot() +
  aes(x = caras, y = prob_obs) +
  geom_bar(stat = "identity") +
  geom_point(aes(y = prob_real), color = "red",   size = 4 ) +
  geom_point(aes(y = prob_est), color = "blue",   size = 2 )+
  geom_line(aes(y = prob_real), color = "red") # Ojo, la linea no tiene interpretación entre dos puntos, pues es la función de masa de una variable aleatoria discreta.
# Out:
# plot without title

# %% [markdown]
# # III) Distribución poisson
# ## Contexto
# Usualmente una variable aleatoria poisson, representa la cantidad de eventos registrados en un interval fijo de tiempo con una cierta tasa de ocurrencia.
# ## Función de probabilidad
#
# $$p(x) = \lambda^x \dfrac{e^{-\lambda}}{x!}$$
#
# Donde $\lambda$ corresponde a la tasa de ocurrencia y $x$ la cantida de eventos observados, pudiendo tomar los valores $x = 0,1,2,...$
#
# ## Funciones en R
#  * `dpois(x, lambda, log = FALSE)`
#  * `ppois(q, lambda, lower.tail = TRUE, log.p = FALSE)`
#  * `qpois(p, lambda, lower.tail = TRUE, log.p = FALSE)`
#  * `rpois(n, lambda)`

# %% [markdown]
# **P5.** Suponga que en un restaurant de comida se tiene una tasa de llegada de clientes de 2 clientes por cada 3 minutos en promedio.
# ¿Cuál es la probabilidad de que 5 o más clientes lleguen en un período de 9 minutos?.

# %%
# La tasa de éxito en una dist. poisson es el parámetro lambda 
# Dada la info, se tiene una tasa de 6 clientes cada 9 minutos
ppois(4, lambda = 6, lower.tail = F) # Hay un 72% de prob de que lleguen 5 o más clientes en un período de 9 minutos.
1-ppois(4, lambda = 6, lower.tail = T)
# Out:
# [1] 0.7149435
# [1] 0.7149435

# %% [markdown]
# **P6.** Se sabe que la tasa de falla en la elaboración de ampolletas sigue una distribución poisson, con una tasa de falla de 3 ampolletas defectuosas por semana.
# ¿Cuál es la probabilidad de que al cabo de un mes se genere un total de 20 ampolletas defectuosas o más?

# %%
# lambda = 3*4 = 12 ampolletas defectuosas por mes (se asume que el mes tien 4 semanas).
ppois(19, lambda = 12, lower.tail = F)# Hay una prob de un 2% de obtener 20 o más ampolletas defectuosas en un mes.
# Out:
# [1] 0.02127977
